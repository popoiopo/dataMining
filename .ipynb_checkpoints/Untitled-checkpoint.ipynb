# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Create smaller csv from big ass dataset
df_training = pd.read_csv("..\..\dataminingData\data\train.csv")

# df_test = pd.read_csv("test.csv")
# print(df_training.shape)
# print(df_test.shape)
# # df_training.head(30).to_csv("testtrain.csv")
# df_training.head(30).to_csv("testtest.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-96fe00109197> in <module>()
#       1 # Create smaller csv from big ass dataset
# ----> 2 df_training = pd.read_csv("..\..\dataminingData\data\train.csv")
#       3
#       4 # df_test = pd.read_csv("test.csv")
#       5 # print(df_training.shape)
#
# c:\users\bastiaan\appdata\local\programs\python\python36\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     707                     skip_blank_lines=skip_blank_lines)
#     708
# --> 709         return _read(filepath_or_buffer, kwds)
#     710
#     711     parser_f.__name__ = name
#
# c:\users\bastiaan\appdata\local\programs\python\python36\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     447
#     448     # Create the parser.
# --> 449     parser = TextFileReader(filepath_or_buffer, **kwds)
#     450
#     451     if chunksize or iterator:
#
# c:\users\bastiaan\appdata\local\programs\python\python36\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     816             self.options['has_index_names'] = kwds['has_index_names']
#     817
# --> 818         self._make_engine(self.engine)
#     819
#     820     def close(self):
#
# c:\users\bastiaan\appdata\local\programs\python\python36\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1047     def _make_engine(self, engine='c'):
#    1048         if engine == 'c':
# -> 1049             self._engine = CParserWrapper(self.f, **self.options)
#    1050         else:
#    1051             if engine == 'python':
#
# c:\users\bastiaan\appdata\local\programs\python\python36\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1693         kwds['allow_leading_cols'] = self.index_col is not False
#    1694
# -> 1695         self._reader = parsers.TextReader(src, **kwds)
#    1696
#    1697         # XXX
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'..\\..\\dataminingData\\data\train.csv' does not exist

# %%
print(df_training["date_time"],
df_test["date_time"])

# %%
# hist = np.histogram(df_training["price_usd"])

# Check totaal aantal hotels en welke er nul zijn
# len(np.unique(df_training["prop_id"]))
# # bookings_whuuuut = len(df_training.loc[(df_training["price_usd"] == 0)])
# # bookings_whuuuut["price_usd"]
# poep = df_training.loc[(df_training["price_usd"] < 0.0001)]
# len(set(poep["prop_id"]))

# Haal de hotels die geloofwaardige prijzen hebben en sorteer deze 
bookings = df_training.loc[(df_training["price_usd"] > 0.05) & (df_training["price_usd"] < 1000)]
sorted_booking = bookings.sort_values(by="price_usd")
# print(sorted_booking)


# prices = df_training['price_usd']
# prices = prices[np.logical_and(prices > 5, prices < 1000)]

# hist = np.histogram(prices, bins=20)
# print(hist)
# plt.hist(prices, bins=20)
# plt.show()

# %% [markdown]
# ### Price per night per room ヽ(´▽`)/

# %%
sorted_booking["ppn_pr"] = sorted_booking["price_usd"] / sorted_booking["srch_room_count"] / sorted_booking["srch_length_of_stay"]

# %%
len(sorted_booking[["ppn_pr", "price_usd"]])
# Out:
# 30

# %% [markdown]
# ### Normalizing prices by country wealth ;()

# %%
# Group by country and update set
grouped = sorted_booking.groupby("prop_country_id")["price_usd"].mean()
sorted_booking = sorted_booking.merge(grouped.to_frame(), left_on='prop_country_id', right_index=True, how='inner').rename(index=str, columns={"price_usd_x": "price_usd", "price_usd_y": "mean_ppc"})
# Out:
# (4944668, 54)
# (4944668, 55)

# %%
# Creating normalizing constant and global mean variable
norm_const = 0.1
glob_mean = np.unique(sorted_booking["mean_ppc"]).mean() #sorted_booking["mean_ppc"].mean()

# Normalize!
sorted_booking["norm_price"] = sorted_booking["price_usd"] + ((glob_mean - sorted_booking["mean_ppc"]) * norm_const)
sorted_booking["norm_price"].loc[sorted_booking["norm_price"] < 0] = sorted_booking["price_usd"]

# Print before and after
sorted_booking[["price_usd","prop_country_id","mean_ppc","norm_price"]]
# Out:
# 177.05336887611637
# 177.05336887611637
# c:\users\bastiaan\appdata\local\programs\python\python36\lib\site-packages\pandas\core\indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
#          price_usd  prop_country_id    mean_ppc  norm_price
# 4499653       0.06               15  218.973256    0.060000
# 4499667       0.06               15  218.973256    0.060000
# 4499651       0.06               15  218.973256    0.060000
# 4499657       0.06               15  218.973256    0.060000
# 4499661       0.06               15  218.973256    0.060000
# 4499673       0.07               15  218.973256    0.070000
# 4499656       0.07               15  218.973256    0.070000
# 4499674       0.08               15  218.973256    0.080000
# 4499676       0.08               15  218.973256    0.080000
# 4499665       0.08               15  218.973256    0.080000
# 4499669       0.08               15  218.973256    0.080000
# 4499668       0.08               15  218.973256    0.080000
# 4499666       0.09               15  218.973256    0.090000
# 4499675       0.09               15  218.973256    0.090000
# 4499652       0.09               15  218.973256    0.090000
# 4499660       0.10               15  218.973256    0.100000
# 4499678       0.10               15  218.973256    0.100000
# 4499650       0.12               15  218.973256    0.120000
# 4499671       0.12               15  218.973256    0.120000
# 4499654       0.13               15  218.973256    0.130000
# 4499662       0.14               15  218.973256    0.140000
# 4499664       0.14               15  218.973256    0.140000
# 4499659       0.16               15  218.973256    0.160000
# 4499655       0.16               15  218.973256    0.160000
# 4499672       0.19               15  218.973256    0.190000
# 4499658       0.19               15  218.973256    0.190000
# 1131369      30.03               15  218.973256   25.838011
# 35943        33.71               15  218.973256   29.518011
# 3008076      34.00               15  218.973256   29.808011
# 2006008      34.13               15  218.973256   29.938011
# ...            ...              ...         ...         ...
# 4567945     528.86               20  385.210533  508.044284
# 2013263     530.43               20  385.210533  509.614284
# 197724      316.00              197  683.857143  265.319623
# 2185417     328.00              197  683.857143  277.319623
# 2356565     354.00              197  683.857143  303.319623
# 1032000     358.00              197  683.857143  307.319623
# 1031998     428.00              197  683.857143  377.319623
# 2356567     464.00              197  683.857143  413.319623
# 2356566     514.00              197  683.857143  463.319623
# 2356569     585.00              197  683.857143  534.319623
# 1032002     602.00              197  683.857143  551.319623
# 1031997     629.00              197  683.857143  578.319623
# 73183       630.00              197  683.857143  579.319623
# 2356570     645.00              197  683.857143  594.319623
# 73184       656.00              197  683.857143  605.319623
# 73188       736.00              197  683.857143  685.319623
# 3559497     769.00              197  683.857143  718.319623
# 2356568     775.00              197  683.857143  724.319623
# 1032001     789.00              197  683.857143  738.319623
# 1031999     795.00              197  683.857143  744.319623
# 1650602     796.00              197  683.857143  745.319623
# 73186       797.00              197  683.857143  746.319623
# 197725      801.00              197  683.857143  750.319623
# 1650604     830.00              197  683.857143  779.319623
# 197727      835.00              197  683.857143  784.319623
# 2356564     853.00              197  683.857143  802.319623
# 3559499     953.00              197  683.857143  902.319623
# 1650605     958.00              197  683.857143  907.319623
# 197728      973.00              197  683.857143  922.319623
# 73189       979.00              197  683.857143  928.319623
#
# [4944668 rows x 4 columns]

# %% [markdown]
# ### History Pricing o.O

# %%
sorted_booking["hist_usd"] = abs(sorted_booking["visitor_hist_adr_usd"] - sorted_booking["price_usd"])
sorted_booking["hist_propstar"] = abs(sorted_booking["visitor_hist_starrating"] - sorted_booking["prop_starrating"])

# %%
print(sorted_booking.shape)
print(sorted_booking["hist_usd"].isnull().sum())
print(sorted_booking["hist_propstar"].isnull().sum())
# Out:
# (4944668, 58)
# 4692151
# 4693271

# %%
# print(sorted_booking[10:20])
bookdict = {}
gekloot = sorted_booking["price_usd"].dropna()
binsize = len(gekloot)/20

for i in range(20):
    begin = int(i * binsize)
    end = int((i+1)* binsize)
    cat = sorted_booking[begin:end]
    bookdict[str(min(cat["price_usd"])) + " -- " + str(max(cat["price_usd"]))] = cat
labels = bookdict.keys()
neen = []
jaan = []
for bin in bookdict.keys():
#     print(bin, "\n", bookdict[bin]["booking_bool"].value_counts()[0])
    neen.append(bookdict[bin]["booking_bool"].value_counts()[0])
    jaan.append(bookdict[bin]["booking_bool"].value_counts()[1])
    
# print(bookdict)

# %%
df_tr = pd.read_csv("testtrain.csv")
df_tr["Missing_Values"] = len(df_tr.columns) - df_tr.apply(lambda x: x.count(), axis=1)
[print(x) for x in df_tr]
print(df_tr.head(5))
print(df_tr.Missing_Values)

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

print(jaan)
print(labels)

raw_data = {'Labels': labels,
        'booked': jaan,
        'not booked': neen}
df = pd.DataFrame(raw_data, columns = ['Labels', 'booked', 'not booked'])
# Setting the positions and width for the bars
pos = list(range(len(df['booked']))) 
width = 0.25 
    
# Plotting the bars
fig, ax = plt.subplots(figsize=(10,5))

# Create a bar with pre_score data,
# in position pos,
plt.bar(pos, 
        #using df['pre_score'] data,
        df['booked'], 
        # of width
        width, 
        # with alpha 0.5
        alpha=0.5, 
        # with color
        color='#EE3224', 
        # with label the first value in first_name
        label=df['Labels']) 

# # Create a bar with mid_score data,
# # in position pos + some width buffer,
# plt.bar([p + width for p in pos], 
#         #using df['mid_score'] data,
#         df['not booked'],
#         # of width
#         width, 
#         # with alpha 0.5
#         alpha=0.5, 
#         # with color
#         color='#F78F1E', 
#         # with label the second value in first_name
#         label=df['Labels']) 

# Set the y axis label
ax.set_ylabel('Amount')

# Set the chart's title
ax.set_title('Amount booked/not booked by price indication')

# Set the position of the x ticks
ax.set_xticks([p + 1.5 * width for p in pos])

# Set the labels for the x ticks
ax.set_xticklabels(df['Labels'][0], rotation='vertical')

# Setting the x-axis and y-axis limits
plt.xlim(min(pos)-width, max(pos)+width*4)
plt.ylim([0, max(df['booked'])+(.1*max(df['booked']))] )

# Adding the legend and showing the plot
plt.legend(['Booked'], loc='upper left')
plt.grid()
plt.show()

# %%
# print(len(abs(sorted_booking["visitor_hist_adr_usd"] - sorted_booking["price_usd"]).dropna()),
# len(np.argwhere(abs(sorted_booking["visitor_hist_adr_usd"] - sorted_booking["price_usd"]).dropna())),
# len(abs(sorted_booking["visitor_hist_adr_usd"] - sorted_booking["price_usd"])),
# len(abs(sorted_booking["visitor_hist_adr_usd"] - sorted_booking["price_usd"]).dropna()) - len(np.argwhere(abs(sorted_booking["visitor_hist_adr_usd"] - sorted_booking["price_usd"]).dropna())))

# print(np.argwhere(abs(sorted_booking["visitor_hist_adr_usd"] - sorted_booking["price_usd"]).dropna()))
# i_hist = np.argwhere(abs(sorted_booking["visitor_hist_adr_usd"] - sorted_booking["price_usd"]).dropna())
# for i in i_hist:
#     print(i[0])
        
sorted_booking["hist_usd"] = abs(sorted_booking["visitor_hist_adr_usd"] - sorted_booking["price_usd"])
sorted_booking["hist_propstar"] = abs(sorted_booking["visitor_hist_starrating"] - sorted_booking["prop_starrating"])

hist_usd_index = np.argwhere(abs(sorted_booking["visitor_hist_adr_usd"] - sorted_booking["price_usd"]).dropna())
# for i in hist_usd_index[:20]:
#     print(i[0])
hist_usd_index
# print(sorted_booking["hist_propstar"].dropna())

# print(len(df_training),len(np.unique(df_training["srch_id"])))
# df_training["date_time"]
